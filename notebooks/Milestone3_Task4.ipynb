# %%
## Task 4

# %% [markdown]
# ### Boxplot of total counts by week day

# %%
sns.boxplot(x="weekday", y="cnt", data=data)

# %% [markdown]
# ### Ratio of registered users to total counts

# %%
sns.relplot(x="dteday", y="registered_ratio", kind="line", ci=None, data=data)

# %% [markdown]
# ### Temperature vs Total Counts

# %%
sns.relplot(x="temp", y="cnt", data=data);

# %% [markdown]
# ### Humidity vs Total Counts

# %%
sns.relplot(x="hum", y="cnt", data=data);

# %% [markdown]
# ## Total Counts vs Holiday?

# %%
sns.boxplot(x="holiday", y="cnt", data=data)

# %% [markdown]
# ## Total Counts by Hours

# %%
sns.boxplot(x="hr", y="cnt", data=data)

# %% [markdown]
# ## Total Counts by Months

# %%
sns.boxplot(x="mnth", y="cnt", data=data)

# %% [markdown]
# ## Obseravations
#
# Summer and spring see the highest total  numbers of users as it is more convenient to get out and ride bikecycles. The demand for bikecycles peak at two periods - 7-8 am and and 5-6 pm which are the beginning and ending a working day. However, the demand does not fluctuate very much with respect to day of the week, while a holiday day sees slightly less demand. The demand for bikecycles  drops as the temperature gets lower. The number of registered users increases  at beginning and end of a year and significantly drops in the middle of a year.
