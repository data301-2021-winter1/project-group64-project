# %% [markdown]
# ## Task 1

# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv('Bike-Sharing-Dataset/hour.csv')

# %% [markdown]
# Show the dataframe headers

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# Let's plot the distribution of column 'cnt'

# %%
sns.histplot(data=data, x="cnt")

# %% [markdown]
# Let's plot the cnt vs time

# %%
sns.relplot(x="dteday", y="cnt", kind="line", ci=None, data=data)

# %% [markdown]
# Let's plot a crossplot of cnt and registered

# %%
sns.relplot(x="cnt", y="registered", data=data);

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### 1. Loading

# %%
data = pd.read_csv('Bike-Sharing-Dataset/hour.csv')

# %% [markdown]
# Print out the column data types and check for missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Show the dataframe headers

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### 2. Clean Data

# %% [markdown]
# Drop column instant since we don't need it

# %%
data.drop('instant', axis=1, inplace=True)

# %%
data.head()
# Out:
#        dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1   0        0        6           0           1
# 1  2011-01-01       1   0     1   1        0        6           0           1
# 2  2011-01-01       1   0     1   2        0        6           0           1
# 3  2011-01-01       1   0     1   3        0        6           0           1
# 4  2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### 3. Process Data

# %% [markdown]
# Calculate registered_ratio and casual_ratio

# %%
data['registered_ratio'] = data['registered']/ data['cnt']
data['casual_ratio'] = data['casual']/ data['cnt']

# %% [markdown]
# ### 4. Wrangle Data

# %% [markdown]
# Replace values in column yr

# %%
data.loc[data['yr']==0,'yr'] = 2011
data.loc[data['yr']==1,'yr'] = 2012

# %%
data.head()
# Out:
#        dteday  season    yr  mnth  hr  holiday  weekday  workingday  \
# 0  2011-01-01       1  2011     1   0        0        6           0
# 1  2011-01-01       1  2011     1   1        0        6           0
# 2  2011-01-01       1  2011     1   2        0        6           0
# 3  2011-01-01       1  2011     1   3        0        6           0
# 4  2011-01-01       1  2011     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#    registered_ratio  casual_ratio
# 0          0.812500      0.187500
# 1          0.800000      0.200000
# 2          0.843750      0.156250
# 3          0.769231      0.230769
# 4          1.000000      0.000000

# %% [markdown]
# ## Task 3

# %% [markdown]
# ### Step 1

# %% [markdown]
# Testing chaining in pandas

# %%
# Method chaining begins
import numpy as np
df = pd.read_csv('Bike-Sharing-Dataset/hour.csv').drop('instant', axis=1).assign(registered_ratio=data['registered']/ data['cnt']).assign(casual_ratio=data['casual']/ data['cnt']).assign(yr=lambda x: np.where(x.yr==0, 2011, 2012))


df
# Out:
#            dteday  season    yr  mnth  hr  holiday  weekday  workingday  \
# 0      2011-01-01       1  2011     1   0        0        6           0
# 1      2011-01-01       1  2011     1   1        0        6           0
# 2      2011-01-01       1  2011     1   2        0        6           0
# 3      2011-01-01       1  2011     1   3        0        6           0
# 4      2011-01-01       1  2011     1   4        0        6           0
# ...           ...     ...   ...   ...  ..      ...      ...         ...
# 17374  2012-12-31       1  2012    12  19        0        1           1
# 17375  2012-12-31       1  2012    12  20        0        1           1
# 17376  2012-12-31       1  2012    12  21        0        1           1
# 17377  2012-12-31       1  2012    12  22        0        1           1
# 17378  2012-12-31       1  2012    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0               1  0.24  0.2879  0.81     0.0000       3          13   16
# 1               1  0.22  0.2727  0.80     0.0000       8          32   40
# 2               1  0.22  0.2727  0.80     0.0000       5          27   32
# 3               1  0.24  0.2879  0.75     0.0000       3          10   13
# 4               1  0.24  0.2879  0.75     0.0000       0           1    1
# ...           ...   ...     ...   ...        ...     ...         ...  ...
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49
#
#        registered_ratio  casual_ratio
# 0              0.812500      0.187500
# 1              0.800000      0.200000
# 2              0.843750      0.156250
# 3              0.769231      0.230769
# 4              1.000000      0.000000
# ...                 ...           ...
# 17374          0.907563      0.092437
# 17375          0.910112      0.089888
# 17376          0.922222      0.077778
# 17377          0.786885      0.213115
# 17378          0.755102      0.244898
#
# [17379 rows x 18 columns]

# %% [markdown]
# Moving chaining parts to a function

# %%
def load_and_process(url_or_path_to_csv_file):
    df = pd.read_csv(url_or_path_to_csv_file).drop('instant', axis=1).assign(registered_ratio=lambda x : x['registered']/ x['cnt']).assign(casual_ratio=data['casual']/ data['cnt']).assign(yr=lambda x: np.where(x.yr==0, 2011, 2012))
    return df

# %%
load_and_process('Bike-Sharing-Dataset/hour.csv')
# Out:
#            dteday  season    yr  mnth  hr  holiday  weekday  workingday  \
# 0      2011-01-01       1  2011     1   0        0        6           0
# 1      2011-01-01       1  2011     1   1        0        6           0
# 2      2011-01-01       1  2011     1   2        0        6           0
# 3      2011-01-01       1  2011     1   3        0        6           0
# 4      2011-01-01       1  2011     1   4        0        6           0
# ...           ...     ...   ...   ...  ..      ...      ...         ...
# 17374  2012-12-31       1  2012    12  19        0        1           1
# 17375  2012-12-31       1  2012    12  20        0        1           1
# 17376  2012-12-31       1  2012    12  21        0        1           1
# 17377  2012-12-31       1  2012    12  22        0        1           1
# 17378  2012-12-31       1  2012    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0               1  0.24  0.2879  0.81     0.0000       3          13   16
# 1               1  0.22  0.2727  0.80     0.0000       8          32   40
# 2               1  0.22  0.2727  0.80     0.0000       5          27   32
# 3               1  0.24  0.2879  0.75     0.0000       3          10   13
# 4               1  0.24  0.2879  0.75     0.0000       0           1    1
# ...           ...   ...     ...   ...        ...     ...         ...  ...
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49
#
#        registered_ratio  casual_ratio
# 0              0.812500      0.187500
# 1              0.800000      0.200000
# 2              0.843750      0.156250
# 3              0.769231      0.230769
# 4              1.000000      0.000000
# ...                 ...           ...
# 17374          0.907563      0.092437
# 17375          0.910112      0.089888
# 17376          0.922222      0.077778
# 17377          0.786885      0.213115
# 17378          0.755102      0.244898
#
# [17379 rows x 18 columns]

# %%
import project_functions
df = project_functions.load_and_process('Bike-Sharing-Dataset/hour.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5d5322aeb59e> in <module>
#       1 import project_functions
# ----> 2 df = project_functions.load_and_process('Bike-Sharing-Dataset/hour.csv')
#       3 df
#
# ~\OneDrive\Desktop\MITE\ds project\project_functions.py in load_and_process(url_or_path_to_csv_file)
#       3
#       4 def load_and_process(url_or_path_to_csv_file):
# ----> 5     df = pd.read_csv(url_or_path_to_csv_file).drop('instant', axis=1).assign(registered_ratio=data['registered']/ data['cnt']).assign(casual_ratio=data['casual']/ data['cnt']).assign(yr=lambda x: np.where(x.yr==0, 2011, 2012))
#       6     return df
#
# NameError: name 'data' is not defined
